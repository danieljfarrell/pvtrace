# %%
from pvtrace.material.lumophore import Lumophore, lumogen_f_red_abs, lumogen_f_red_ems
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(200, 800, 400)
plt.plot(x, lumogen_f_red_abs(x))
plt.plot(x, lumogen_f_red_ems(x))

# %%
lum = Lumophore.make_lumogen_f_red(x, 1000.0, 1.0)
plt.plot(x, lum.absorption_coefficient(x))
plt.plot(x, lum.emission_spectrum(x))

# %%
lum.emission_spectrum([555, 560, 565, 570, 575, 580, 585])
# Out:
# array([0.25693299, 0.34173081, 0.43949733, 0.54659885, 0.65738259,
#        0.76451534, 0.85979304])

# %%
y = lumogen_f_red_abs(x)
x[np.isfinite(y) == False]
# Out:
# array([], dtype=float64)
